# %%
import numpy as np
import matplotlib.pyplot as plt

# 设置Pareto分布的参数
alpha = 2.0  # 形状参数
size = 1000  # 样本大小
x_m = 1      # 最小值

# 生成符合Pareto分布的样本
samples = (np.random.pareto(alpha, size) + 1) * x_m

# 绘制样本的直方图
plt.hist(samples, bins=50, density=True, alpha=0.6, color='g')

# 绘制理论概率密度函数
x = np.linspace(x_m, samples.max(), 100)
pdf = (alpha * x_m**alpha) / (x**(alpha + 1))
plt.plot(x, pdf, 'r-', linewidth=2)

plt.title('Samples from Pareto Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()
